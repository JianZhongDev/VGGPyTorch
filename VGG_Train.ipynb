# %% [markdown]
# # VGG_Train
# DESCRIPTION: This notebook includes training and validation scripts for VGG model.
#
# @author: Jian Zhong

# %%
## import modules
import os
import time
import datetime

import functools

import numpy as np
import matplotlib.pyplot as plt

import torch
import torchvision
from torchvision.transforms import v2

import importlib

# %%
## import customized modules 
import Modules.Models.VGG as VGG
from Modules.Data.Transforms import (
    subtract_channel_mean, 
    subtract_const, 
    random_ch_shift_pca,
)
from Modules.TrainAndValidate.TrainValidate import (
    train_one_epoch, 
    validate_one_epoch, 
    validate_one_epoch_topk, 
    validate_one_epoch_topk_aug,
)

# %%
## create data transforms

## subtract global mean channel background
train_data_ch_avg = torch.tensor([[[0.4914]],[[0.4822]],[[0.4465]]])
print(train_data_ch_avg.size())
subtract_ch_avg = functools.partial(subtract_const, const_val = train_data_ch_avg)

## random channel shifts
trainset_pca_eigenvecs = torch.tensor([[-0.5580,  0.7063,  0.4356], [-0.5775,  0.0464, -0.8151], [-0.5960, -0.7063,  0.3820]])
print(trainset_pca_eigenvecs.size())
trainset_pca_eigenvals = torch.tensor([0.1719, 0.0139, 0.0029])
print(trainset_pca_eigenvals.size())

random_ch_shift = functools.partial(random_ch_shift_pca, 
                                    pca_eigenvecs = trainset_pca_eigenvecs,
                                    pca_eigenvals = trainset_pca_eigenvals,
                                    random_paras = {"mean": 0, "std": 0.1},
                                   )
# Out:
# torch.Size([3, 1, 1])
# torch.Size([3, 3])
# torch.Size([3])

# %%
## define transform

## data transform for training
train_data_transforms = v2.Compose([
    v2.ToImage(),
    v2.ToDtype(torch.float32,scale = True),
    v2.Lambda(subtract_ch_avg),
    v2.RandomHorizontalFlip(0.5),
    v2.Lambda(random_ch_shift),
])

## data transform for validation
validate_data_transforms = v2.Compose([
    v2.ToImage(),
    v2.ToDtype(torch.float32,scale = True),
    v2.Lambda(subtract_ch_avg),
])

# %%
## load data set

## NOTE: the dataset_root_dir may need to be changed accordingly
dataset_root_dir = r"E:\Python\DataSet\TorchDataSet\CIFAR10"
train_data = torchvision.datasets.CIFAR10(
    root = dataset_root_dir,
    train = True,
    download = True,
    transform=train_data_transforms,
)
validate_data = torchvision.datasets.CIFAR10(
    root = dataset_root_dir,
    train = False,
    download = True,
    transform=validate_data_transforms,
)

print(f"train_data length: {len(train_data)}")
print(f"validate_data lenght: {len(validate_data)}")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# train_data length: 50000
# validate_data lenght: 10000

# %%
## create data loader

train_batch_size = 128
validate_batch_size = 128

train_dataloader = torch.utils.data.DataLoader(train_data, batch_size = train_batch_size, shuffle = True)
validate_dataloader = torch.utils.data.DataLoader(validate_data, batch_size = validate_batch_size, shuffle = True)

# %%
## check data

check_dataloader = train_dataloader

check_features, check_labels = next(iter(check_dataloader))

print(f"Feature batch shape: {check_features.size()}")
print(f"Labels batch shape: {check_labels.size()}")

check_image = check_features[0].squeeze().numpy()
check_label = check_labels[0].numpy()

plt.figure()
for i_ch in range(check_image.shape[0]):
    plt.hist(check_image[i_ch,...].reshape((-1,)), label = f"ch{i_ch}")
plt.legend()
plt.title(f"transformed image channel histogram")
plt.show()

plt.figure()
plt.imshow(np.rollaxis(check_image, 0, 3))
plt.title(f"transformed image, label = {check_label}")
plt.show()
# Out:
# Feature batch shape: torch.Size([128, 3, 32, 32])
# Labels batch shape: torch.Size([128])
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
## define model

model_stacked_conv_list = [
    [ 
        {"nof_layers": 1, "in_channels": 3, "out_channels": 128,}, 
    
    ],
    [ 
        {"nof_layers": 1, "in_ckjhannels": 128, "out_channels": 256,}, 
    ],
    [ 
        {"nof_layers": 1, "in_channels": 256, "out_channels": 512, }, 
    ],
]

model_stacked_linear = [
    { "nof_layers": 1, "in_features": 4 * 4 * 512, "out_features": 1024, "dropout_p": 0.5},
    { "nof_layers": 1, "in_features": 1024, "out_features": 10, "activation": None}
]

model = VGG.VGG(
    stacked_conv_descriptors = model_stacked_conv_list,
    stacked_linear_descriptor = model_stacked_linear,
    enable_debug = False,
)

print(model)
# Out:
# VGG(
#   (network): Sequential(
#     (0): VGGStacked2DConv(
#       (network): Sequential(
#         (0): Conv2d(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#       )
#     )
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): VGGStacked2DConv(
#       (network): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#       )
#     )
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): VGGStacked2DConv(
#       (network): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#       )
#     )
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Flatten(start_dim=1, end_dim=-1)
#     (7): VGGStackedLinear(
#       (network): Sequential(
#         (0): Linear(in_features=8192, out_features=1024, bias=True)
#         (1): ReLU()
#         (2): Dropout(p=0.5, inplace=False)
#         (3): Linear(in_features=1024, out_features=10, bias=True)
#       )
#     )
#     (8): Softmax(dim=-1)
#   )
# )

# %%
## quickly confirm that model can run

model.to("cpu")
with torch.no_grad():
    check_features, check_labels = next(iter(train_dataloader))
    model.eval()
    print(model(check_features).size())
# Out:
# torch.Size([128, 10])

# %%
## training configuration

loss_func = torch.nn.CrossEntropyLoss()

optimizer = torch.optim.SGD(model.parameters(), lr = 1E-2, momentum = 0.9, weight_decay= 5E-4)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer = optimizer,
    mode = "max",
    factor = 0.1,
    patience = 10,
    threshold = 1E-3,
    min_lr = 0,
)

top_k = 1

validate_transforms = [None, torchvision.transforms.functional.hflip]

nof_epochs = 200

# %%
## use parallel computing if possible

device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)

print(f"Using {device} device")

model = model.to(device)
# Out:
# Using cuda device

# %%
## training and validationg loop

learning_rates = torch.zeros((nof_epochs,))
train_losses = torch.zeros((nof_epochs,))
validate_losses = torch.zeros((nof_epochs,))
validate_accuracies = torch.zeros((nof_epochs,))

for i_epoch in range(nof_epochs):
    print(f" ------ Epoch {i_epoch} ------ ")

    cur_lr = optimizer.param_groups[0]['lr'];
    
    print(f"current lr = {cur_lr}")
    learning_rates[i_epoch] = cur_lr

    cur_train_loss = train_one_epoch(model, 
                                     train_dataloader,  
                                     loss_func, 
                                     optimizer, 
                                     device)
    cur_validate_loss, cur_validate_accuracy = validate_one_epoch_topk_aug(model, 
                                                                           validate_dataloader, 
                                                                           loss_func, 
                                                                           validate_transforms, 
                                                                           device, 
                                                                           top_k)
    
    train_losses[i_epoch] = cur_train_loss
    validate_losses[i_epoch] =  cur_validate_loss
    validate_accuracies[i_epoch] = cur_validate_accuracy

    scheduler.step(cur_validate_accuracy)
    
    print("\n")
# Out:
#  ------ Epoch 0 ------
# current lr = 0.01
# batch 0 loss: 2.302647
# batch 100 loss: 2.302406
# batch 200 loss: 2.302171
# batch 300 loss: 2.301939
# Train: Avg loss: 2.301619
# Validate: top1 Accuracy: 13.23%, Avg loss: 2.299846
#
#
#  ------ Epoch 1 ------
# current lr = 0.01
# batch 0 loss: 2.300517
# batch 100 loss: 2.298548
# batch 200 loss: 2.294273
# batch 300 loss: 2.280733
# Train: Avg loss: 2.265321
# Validate: top1 Accuracy: 24.97%, Avg loss: 2.196523
#
#
#  ------ Epoch 2 ------
# current lr = 0.01
# batch 0 loss: 2.218044
# batch 100 loss: 2.196369
# batch 200 loss: 2.189939
# batch 300 loss: 2.185093
# Train: Avg loss: 2.178850
# Validate: top1 Accuracy: 32.06%, Avg loss: 2.137053
#
#
#  ------ Epoch 3 ------
# current lr = 0.01
# batch 0 loss: 2.134573
# batch 100 loss: 2.156714
# batch 200 loss: 2.144233
# batch 300 loss: 2.136544
# Train: Avg loss: 2.132265
# Validate: top1 Accuracy: 36.29%, Avg loss: 2.093239
#
#
#  ------ Epoch 4 ------
# current lr = 0.01
# batch 0 loss: 2.161665
# batch 100 loss: 2.108948
# batch 200 loss: 2.098788
# batch 300 loss: 2.097562
# Train: Avg loss: 2.094332
# Validate: top1 Accuracy: 39.65%, Avg loss: 2.065540
#
#
#  ------ Epoch 5 ------
# current lr = 0.01
# batch 0 loss: 2.133058
# batch 100 loss: 2.074748
# batch 200 loss: 2.070875
# batch 300 loss: 2.067011
# Train: Avg loss: 2.063592
# Validate: top1 Accuracy: 42.41%, Avg loss: 2.034589
#
#
#  ------ Epoch 6 ------
# current lr = 0.01
# batch 0 loss: 2.123394
# batch 100 loss: 2.042036
# batch 200 loss: 2.040735
# batch 300 loss: 2.039038
# Train: Avg loss: 2.038332
# Validate: top1 Accuracy: 44.14%, Avg loss: 2.016837
#
#
#  ------ Epoch 7 ------
# current lr = 0.01
# batch 0 loss: 1.947069
# batch 100 loss: 2.020927
# batch 200 loss: 2.018617
# batch 300 loss: 2.015886
# Train: Avg loss: 2.015083
# Validate: top1 Accuracy: 46.92%, Avg loss: 1.990371
#
#
#  ------ Epoch 8 ------
# current lr = 0.01
# batch 0 loss: 1.974257
# batch 100 loss: 2.003372
# batch 200 loss: 1.998521
# batch 300 loss: 1.994615
# Train: Avg loss: 1.993981
# Validate: top1 Accuracy: 49.28%, Avg loss: 1.969115
#
#
#  ------ Epoch 9 ------
# current lr = 0.01
# batch 0 loss: 1.932797
# batch 100 loss: 1.990190
# batch 200 loss: 1.986131
# batch 300 loss: 1.981897
# Train: Avg loss: 1.978139
# Validate: top1 Accuracy: 50.48%, Avg loss: 1.958667
#
#
#  ------ Epoch 10 ------
# current lr = 0.01
# batch 0 loss: 1.897076
# batch 100 loss: 1.961945
# batch 200 loss: 1.960825
# batch 300 loss: 1.960986
# Train: Avg loss: 1.961590
# Validate: top1 Accuracy: 51.60%, Avg loss: 1.942503
#
#
#  ------ Epoch 11 ------
# current lr = 0.01
# batch 0 loss: 1.992283
# batch 100 loss: 1.950453
# batch 200 loss: 1.948844
# batch 300 loss: 1.947278
# Train: Avg loss: 1.948380
# Validate: top1 Accuracy: 53.74%, Avg loss: 1.924939
#
#
#  ------ Epoch 12 ------
# current lr = 0.01
# batch 0 loss: 1.934816
# batch 100 loss: 1.935045
# batch 200 loss: 1.931172
# batch 300 loss: 1.931992
# Train: Avg loss: 1.930507
# Validate: top1 Accuracy: 53.48%, Avg loss: 1.925049
#
#
#  ------ Epoch 13 ------
# current lr = 0.01
# batch 0 loss: 1.922955
# batch 100 loss: 1.922767
# batch 200 loss: 1.922626
# batch 300 loss: 1.921085
# Train: Avg loss: 1.918258
# Validate: top1 Accuracy: 56.72%, Avg loss: 1.898082
#
#
#  ------ Epoch 14 ------
# current lr = 0.01
# batch 0 loss: 1.888779
# batch 100 loss: 1.911934
# batch 200 loss: 1.906753
# batch 300 loss: 1.903464
# Train: Avg loss: 1.903881
# Validate: top1 Accuracy: 57.25%, Avg loss: 1.891752
#
#
#  ------ Epoch 15 ------
# current lr = 0.01
# batch 0 loss: 1.843251
# batch 100 loss: 1.894749
# batch 200 loss: 1.892926
# batch 300 loss: 1.889322
# Train: Avg loss: 1.888042
# Validate: top1 Accuracy: 59.86%, Avg loss: 1.869836
#
#
#  ------ Epoch 16 ------
# current lr = 0.01
# batch 0 loss: 1.834020
# batch 100 loss: 1.885109
# batch 200 loss: 1.880713
# batch 300 loss: 1.878305
# Train: Avg loss: 1.876667
# Validate: top1 Accuracy: 58.99%, Avg loss: 1.876115
#
#
#  ------ Epoch 17 ------
# current lr = 0.01
# batch 0 loss: 1.789198
# batch 100 loss: 1.873427
# batch 200 loss: 1.870127
# batch 300 loss: 1.867316
# Train: Avg loss: 1.865645
# Validate: top1 Accuracy: 60.76%, Avg loss: 1.858521
#
#
#  ------ Epoch 18 ------
# current lr = 0.01
# batch 0 loss: 1.851433
# batch 100 loss: 1.857806
# batch 200 loss: 1.857282
# batch 300 loss: 1.853900
# Train: Avg loss: 1.851839
# Validate: top1 Accuracy: 62.94%, Avg loss: 1.838323
#
#
#  ------ Epoch 19 ------
# current lr = 0.01
# batch 0 loss: 1.850595
# batch 100 loss: 1.848499
# batch 200 loss: 1.842665
# batch 300 loss: 1.840990
# Train: Avg loss: 1.840213
# Validate: top1 Accuracy: 63.33%, Avg loss: 1.832669
#
#
#  ------ Epoch 20 ------
# current lr = 0.01
# batch 0 loss: 1.801539
# batch 100 loss: 1.832940
# batch 200 loss: 1.831222
# batch 300 loss: 1.829798
# Train: Avg loss: 1.829339
# Validate: top1 Accuracy: 64.49%, Avg loss: 1.821661
#
#
#  ------ Epoch 21 ------
# current lr = 0.01
# batch 0 loss: 1.791595
# batch 100 loss: 1.818774
# batch 200 loss: 1.820529
# batch 300 loss: 1.820389
# Train: Avg loss: 1.819526
# Validate: top1 Accuracy: 64.98%, Avg loss: 1.821078
#
#
#  ------ Epoch 22 ------
# current lr = 0.01
# batch 0 loss: 1.874179
# batch 100 loss: 1.819760
# batch 200 loss: 1.812889
# batch 300 loss: 1.812383
# Train: Avg loss: 1.811879
# Validate: top1 Accuracy: 65.85%, Avg loss: 1.808471
#
#
#  ------ Epoch 23 ------
# current lr = 0.01
# batch 0 loss: 1.822008
# batch 100 loss: 1.798982
# batch 200 loss: 1.799937
# batch 300 loss: 1.800561
# Train: Avg loss: 1.800754
# Validate: top1 Accuracy: 67.04%, Avg loss: 1.800623
#
#
#  ------ Epoch 24 ------
# current lr = 0.01
# batch 0 loss: 1.814773
# batch 100 loss: 1.791403
# batch 200 loss: 1.793786
# batch 300 loss: 1.793953
# Train: Avg loss: 1.793798
# Validate: top1 Accuracy: 67.38%, Avg loss: 1.796610
#
#
#  ------ Epoch 25 ------
# current lr = 0.01
# batch 0 loss: 1.808808
# batch 100 loss: 1.788448
# batch 200 loss: 1.787063
# batch 300 loss: 1.786412
# Train: Avg loss: 1.785878
# Validate: top1 Accuracy: 67.63%, Avg loss: 1.795585
#
#
#  ------ Epoch 26 ------
# current lr = 0.01
# batch 0 loss: 1.752571
# batch 100 loss: 1.777134
# batch 200 loss: 1.778061
# batch 300 loss: 1.778030
# Train: Avg loss: 1.778037
# Validate: top1 Accuracy: 68.28%, Avg loss: 1.786348
#
#
#  ------ Epoch 27 ------
# current lr = 0.01
# batch 0 loss: 1.817110
# batch 100 loss: 1.774121
# batch 200 loss: 1.773031
# batch 300 loss: 1.771594
# Train: Avg loss: 1.771524
# Validate: top1 Accuracy: 70.20%, Avg loss: 1.769491
#
#
#  ------ Epoch 28 ------
# current lr = 0.01
# batch 0 loss: 1.731912
# batch 100 loss: 1.768602
# batch 200 loss: 1.768005
# batch 300 loss: 1.766210
# Train: Avg loss: 1.765593
# Validate: top1 Accuracy: 70.61%, Avg loss: 1.760287
#
#
#  ------ Epoch 29 ------
# current lr = 0.01
# batch 0 loss: 1.862845
# batch 100 loss: 1.759801
# batch 200 loss: 1.759337
# batch 300 loss: 1.758504
# Train: Avg loss: 1.756208
# Validate: top1 Accuracy: 70.24%, Avg loss: 1.765998
#
#
#  ------ Epoch 30 ------
# current lr = 0.01
# batch 0 loss: 1.774877
# batch 100 loss: 1.750905
# batch 200 loss: 1.749062
# batch 300 loss: 1.749625
# Train: Avg loss: 1.749933
# Validate: top1 Accuracy: 70.65%, Avg loss: 1.760634
#
#
#  ------ Epoch 31 ------
# current lr = 0.01
# batch 0 loss: 1.742491
# batch 100 loss: 1.735724
# batch 200 loss: 1.745778
# batch 300 loss: 1.747836
# Train: Avg loss: 1.745587
# Validate: top1 Accuracy: 71.17%, Avg loss: 1.760287
#
#
#  ------ Epoch 32 ------
# current lr = 0.01
# batch 0 loss: 1.742554
# batch 100 loss: 1.744646
# batch 200 loss: 1.740339
# batch 300 loss: 1.738098
# Train: Avg loss: 1.738248
# Validate: top1 Accuracy: 71.65%, Avg loss: 1.754110
#
#
#  ------ Epoch 33 ------
# current lr = 0.01
# batch 0 loss: 1.774892
# batch 100 loss: 1.734719
# batch 200 loss: 1.733584
# batch 300 loss: 1.734788
# Train: Avg loss: 1.733872
# Validate: top1 Accuracy: 70.76%, Avg loss: 1.762113
#
#
#  ------ Epoch 34 ------
# current lr = 0.01
# batch 0 loss: 1.774084
# batch 100 loss: 1.732153
# batch 200 loss: 1.729260
# batch 300 loss: 1.728341
# Train: Avg loss: 1.728062
# Validate: top1 Accuracy: 72.40%, Avg loss: 1.743829
#
#
#  ------ Epoch 35 ------
# current lr = 0.01
# batch 0 loss: 1.741711
# batch 100 loss: 1.725676
# batch 200 loss: 1.722527
# batch 300 loss: 1.722696
# Train: Avg loss: 1.724271
# Validate: top1 Accuracy: 72.73%, Avg loss: 1.743146
#
#
#  ------ Epoch 36 ------
# current lr = 0.01
# batch 0 loss: 1.746367
# batch 100 loss: 1.718188
# batch 200 loss: 1.720127
# batch 300 loss: 1.720816
# Train: Avg loss: 1.719528
# Validate: top1 Accuracy: 73.33%, Avg loss: 1.736731
#
#
#  ------ Epoch 37 ------
# current lr = 0.01
# batch 0 loss: 1.717287
# batch 100 loss: 1.719934
# batch 200 loss: 1.716372
# batch 300 loss: 1.717198
# Train: Avg loss: 1.715977
# Validate: top1 Accuracy: 74.62%, Avg loss: 1.728885
#
#
#  ------ Epoch 38 ------
# current lr = 0.01
# batch 0 loss: 1.702073
# batch 100 loss: 1.704439
# batch 200 loss: 1.709671
# batch 300 loss: 1.709793
# Train: Avg loss: 1.710185
# Validate: top1 Accuracy: 72.87%, Avg loss: 1.738405
#
#
#  ------ Epoch 39 ------
# current lr = 0.01
# batch 0 loss: 1.700632
# batch 100 loss: 1.708882
# batch 200 loss: 1.706428
# batch 300 loss: 1.706784
# Train: Avg loss: 1.707641
# Validate: top1 Accuracy: 72.46%, Avg loss: 1.742480
#
#
#  ------ Epoch 40 ------
# current lr = 0.01
# batch 0 loss: 1.682841
# batch 100 loss: 1.697467
# batch 200 loss: 1.701364
# batch 300 loss: 1.700858
# Train: Avg loss: 1.700999
# Validate: top1 Accuracy: 75.10%, Avg loss: 1.722619
#
#
#  ------ Epoch 41 ------
# current lr = 0.01
# batch 0 loss: 1.615697
# batch 100 loss: 1.698721
# batch 200 loss: 1.699078
# batch 300 loss: 1.696856
# Train: Avg loss: 1.695832
# Validate: top1 Accuracy: 75.04%, Avg loss: 1.722625
#
#
#  ------ Epoch 42 ------
# current lr = 0.01
# batch 0 loss: 1.690566
# batch 100 loss: 1.689383
# batch 200 loss: 1.690991
# batch 300 loss: 1.690594
# Train: Avg loss: 1.692172
# Validate: top1 Accuracy: 74.44%, Avg loss: 1.722760
#
#
#  ------ Epoch 43 ------
# current lr = 0.01
# batch 0 loss: 1.680801
# batch 100 loss: 1.687446
# batch 200 loss: 1.686422
# batch 300 loss: 1.685367
# Train: Avg loss: 1.686858
# Validate: top1 Accuracy: 75.76%, Avg loss: 1.713018
#
#
#  ------ Epoch 44 ------
# current lr = 0.01
# batch 0 loss: 1.699297
# batch 100 loss: 1.686654
# batch 200 loss: 1.686171
# batch 300 loss: 1.686406
# Train: Avg loss: 1.687328
# Validate: top1 Accuracy: 74.26%, Avg loss: 1.725072
#
#
#  ------ Epoch 45 ------
# current lr = 0.01
# batch 0 loss: 1.722836
# batch 100 loss: 1.677452
# batch 200 loss: 1.676838
# batch 300 loss: 1.676910
# Train: Avg loss: 1.679669
# Validate: top1 Accuracy: 76.31%, Avg loss: 1.705225
#
#
#  ------ Epoch 46 ------
# current lr = 0.01
# batch 0 loss: 1.625399
# batch 100 loss: 1.681078
# batch 200 loss: 1.683012
# batch 300 loss: 1.682041
# Train: Avg loss: 1.680925
# Validate: top1 Accuracy: 76.39%, Avg loss: 1.705356
#
#
#  ------ Epoch 47 ------
# current lr = 0.01
# batch 0 loss: 1.665526
# batch 100 loss: 1.675205
# batch 200 loss: 1.675304
# batch 300 loss: 1.674621
# Train: Avg loss: 1.674156
# Validate: top1 Accuracy: 76.06%, Avg loss: 1.709908
#
#
#  ------ Epoch 48 ------
# current lr = 0.01
# batch 0 loss: 1.732508
# batch 100 loss: 1.678432
# batch 200 loss: 1.674064
# batch 300 loss: 1.671122
# Train: Avg loss: 1.671413
# Validate: top1 Accuracy: 76.46%, Avg loss: 1.703437
#
#
#  ------ Epoch 49 ------
# current lr = 0.01
# batch 0 loss: 1.675919
# batch 100 loss: 1.665979
# batch 200 loss: 1.667024
# batch 300 loss: 1.665771
# Train: Avg loss: 1.665981
# Validate: top1 Accuracy: 76.71%, Avg loss: 1.702143
#
#
#  ------ Epoch 50 ------
# current lr = 0.01
# batch 0 loss: 1.672484
# batch 100 loss: 1.663558
# batch 200 loss: 1.664788
# batch 300 loss: 1.665149
# Train: Avg loss: 1.665600
# Validate: top1 Accuracy: 76.44%, Avg loss: 1.705321
#
#
#  ------ Epoch 51 ------
# current lr = 0.01
# batch 0 loss: 1.671239
# batch 100 loss: 1.662432
# batch 200 loss: 1.664215
# batch 300 loss: 1.661783
# Train: Avg loss: 1.661517
# Validate: top1 Accuracy: 76.84%, Avg loss: 1.702115
#
#
#  ------ Epoch 52 ------
# current lr = 0.01
# batch 0 loss: 1.666162
# batch 100 loss: 1.659469
# batch 200 loss: 1.660874
# batch 300 loss: 1.659373
# Train: Avg loss: 1.658422
# Validate: top1 Accuracy: 77.36%, Avg loss: 1.696591
#
#
#  ------ Epoch 53 ------
# current lr = 0.01
# batch 0 loss: 1.693355
# batch 100 loss: 1.653389
# batch 200 loss: 1.653852
# batch 300 loss: 1.655564
# Train: Avg loss: 1.655764
# Validate: top1 Accuracy: 77.88%, Avg loss: 1.691929
#
#
#  ------ Epoch 54 ------
# current lr = 0.01
# batch 0 loss: 1.613963
# batch 100 loss: 1.652124
# batch 200 loss: 1.655428
# batch 300 loss: 1.655385
# Train: Avg loss: 1.654623
# Validate: top1 Accuracy: 77.94%, Avg loss: 1.692550
#
#
#  ------ Epoch 55 ------
# current lr = 0.01
# batch 0 loss: 1.691458
# batch 100 loss: 1.650226
# batch 200 loss: 1.646303
# batch 300 loss: 1.647825
# Train: Avg loss: 1.648897
# Validate: top1 Accuracy: 77.03%, Avg loss: 1.701421
#
#
#  ------ Epoch 56 ------
# current lr = 0.01
# batch 0 loss: 1.645180
# batch 100 loss: 1.648953
# batch 200 loss: 1.647263
# batch 300 loss: 1.647742
# Train: Avg loss: 1.647832
# Validate: top1 Accuracy: 77.59%, Avg loss: 1.695245
#
#
#  ------ Epoch 57 ------
# current lr = 0.01
# batch 0 loss: 1.610294
# batch 100 loss: 1.640804
# batch 200 loss: 1.642995
# batch 300 loss: 1.643221
# Train: Avg loss: 1.644321
# Validate: top1 Accuracy: 78.16%, Avg loss: 1.690690
#
#
#  ------ Epoch 58 ------
# current lr = 0.01
# batch 0 loss: 1.629003
# batch 100 loss: 1.640168
# batch 200 loss: 1.641422
# batch 300 loss: 1.641071
# Train: Avg loss: 1.641522
# Validate: top1 Accuracy: 78.14%, Avg loss: 1.689925
#
#
#  ------ Epoch 59 ------
# current lr = 0.01
# batch 0 loss: 1.618424
# batch 100 loss: 1.638808
# batch 200 loss: 1.637463
# batch 300 loss: 1.637449
# Train: Avg loss: 1.638371
# Validate: top1 Accuracy: 78.08%, Avg loss: 1.690880
#
#
#  ------ Epoch 60 ------
# current lr = 0.01
# batch 0 loss: 1.667961
# batch 100 loss: 1.634835
# batch 200 loss: 1.637817
# batch 300 loss: 1.638448
# Train: Avg loss: 1.638090
# Validate: top1 Accuracy: 78.59%, Avg loss: 1.685447
#
#
#  ------ Epoch 61 ------
# current lr = 0.01
# batch 0 loss: 1.673635
# batch 100 loss: 1.632850
# batch 200 loss: 1.636146
# batch 300 loss: 1.637050
# Train: Avg loss: 1.635805
# Validate: top1 Accuracy: 78.35%, Avg loss: 1.687462
#
#
#  ------ Epoch 62 ------
# current lr = 0.01
# batch 0 loss: 1.646823
# batch 100 loss: 1.633036
# batch 200 loss: 1.632003
# batch 300 loss: 1.635002
# Train: Avg loss: 1.633783
# Validate: top1 Accuracy: 78.82%, Avg loss: 1.683360
#
#
#  ------ Epoch 63 ------
# current lr = 0.01
# batch 0 loss: 1.614211
# batch 100 loss: 1.623135
# batch 200 loss: 1.625732
# batch 300 loss: 1.629450
# Train: Avg loss: 1.630515
# Validate: top1 Accuracy: 78.93%, Avg loss: 1.684656
#
#
#  ------ Epoch 64 ------
# current lr = 0.01
# batch 0 loss: 1.583316
# batch 100 loss: 1.625107
# batch 200 loss: 1.627220
# batch 300 loss: 1.627410
# Train: Avg loss: 1.628417
# Validate: top1 Accuracy: 78.98%, Avg loss: 1.682305
#
#
#  ------ Epoch 65 ------
# current lr = 0.01
# batch 0 loss: 1.636009
# batch 100 loss: 1.624647
# batch 200 loss: 1.626989
# batch 300 loss: 1.627526
# Train: Avg loss: 1.627049
# Validate: top1 Accuracy: 79.16%, Avg loss: 1.678901
#
#
#  ------ Epoch 66 ------
# current lr = 0.01
# batch 0 loss: 1.590739
# batch 100 loss: 1.625529
# batch 200 loss: 1.624357
# batch 300 loss: 1.622345
# Train: Avg loss: 1.623112
# Validate: top1 Accuracy: 79.60%, Avg loss: 1.677826
#
#
#  ------ Epoch 67 ------
# current lr = 0.01
# batch 0 loss: 1.592392
# batch 100 loss: 1.621711
# batch 200 loss: 1.621129
# batch 300 loss: 1.621541
# Train: Avg loss: 1.621564
# Validate: top1 Accuracy: 79.30%, Avg loss: 1.681422
#
#
#  ------ Epoch 68 ------
# current lr = 0.01
# batch 0 loss: 1.579605
# batch 100 loss: 1.615697
# batch 200 loss: 1.615080
# batch 300 loss: 1.616494
# Train: Avg loss: 1.619433
# Validate: top1 Accuracy: 77.47%, Avg loss: 1.693585
#
#
#  ------ Epoch 69 ------
# current lr = 0.01
# batch 0 loss: 1.630299
# batch 100 loss: 1.621210
# batch 200 loss: 1.620535
# batch 300 loss: 1.619398
# Train: Avg loss: 1.619354
# Validate: top1 Accuracy: 79.27%, Avg loss: 1.678255
#
#
#  ------ Epoch 70 ------
# current lr = 0.01
# batch 0 loss: 1.610751
# batch 100 loss: 1.614553
# batch 200 loss: 1.613558
# batch 300 loss: 1.617175
# Train: Avg loss: 1.616746
# Validate: top1 Accuracy: 79.58%, Avg loss: 1.676948
#
#
#  ------ Epoch 71 ------
# current lr = 0.01
# batch 0 loss: 1.582406
# batch 100 loss: 1.608077
# batch 200 loss: 1.610733
# batch 300 loss: 1.611423
# Train: Avg loss: 1.612487
# Validate: top1 Accuracy: 79.70%, Avg loss: 1.676374
#
#
#  ------ Epoch 72 ------
# current lr = 0.01
# batch 0 loss: 1.606555
# batch 100 loss: 1.607442
# batch 200 loss: 1.609506
# batch 300 loss: 1.609905
# Train: Avg loss: 1.610342
# Validate: top1 Accuracy: 78.40%, Avg loss: 1.688555
#
#
#  ------ Epoch 73 ------
# current lr = 0.01
# batch 0 loss: 1.627954
# batch 100 loss: 1.609433
# batch 200 loss: 1.607729
# batch 300 loss: 1.609353
# Train: Avg loss: 1.610310
# Validate: top1 Accuracy: 80.27%, Avg loss: 1.670169
#
#
#  ------ Epoch 74 ------
# current lr = 0.01
# batch 0 loss: 1.580977
# batch 100 loss: 1.603429
# batch 200 loss: 1.605576
# batch 300 loss: 1.605876
# Train: Avg loss: 1.605903
# Validate: top1 Accuracy: 79.61%, Avg loss: 1.677220
#
#
#  ------ Epoch 75 ------
# current lr = 0.01
# batch 0 loss: 1.595551
# batch 100 loss: 1.601874
# batch 200 loss: 1.600573
# batch 300 loss: 1.604830
# Train: Avg loss: 1.605506
# Validate: top1 Accuracy: 79.47%, Avg loss: 1.677250
#
#
#  ------ Epoch 76 ------
# current lr = 0.01
# batch 0 loss: 1.687510
# batch 100 loss: 1.602676
# batch 200 loss: 1.602068
# batch 300 loss: 1.602518
# Train: Avg loss: 1.603104
# Validate: top1 Accuracy: 80.27%, Avg loss: 1.672805
#
#
#  ------ Epoch 77 ------
# current lr = 0.01
# batch 0 loss: 1.612858
# batch 100 loss: 1.600171
# batch 200 loss: 1.604866
# batch 300 loss: 1.604462
# Train: Avg loss: 1.602895
# Validate: top1 Accuracy: 79.55%, Avg loss: 1.677353
#
#
#  ------ Epoch 78 ------
# current lr = 0.01
# batch 0 loss: 1.561144
# batch 100 loss: 1.598989
# batch 200 loss: 1.598432
# batch 300 loss: 1.599340
# Train: Avg loss: 1.599455
# Validate: top1 Accuracy: 80.17%, Avg loss: 1.669375
#
#
#  ------ Epoch 79 ------
# current lr = 0.01
# batch 0 loss: 1.609488
# batch 100 loss: 1.598797
# batch 200 loss: 1.598637
# batch 300 loss: 1.597475
# Train: Avg loss: 1.597507
# Validate: top1 Accuracy: 80.20%, Avg loss: 1.670715
#
#
#  ------ Epoch 80 ------
# current lr = 0.01
# batch 0 loss: 1.555178
# batch 100 loss: 1.594477
# batch 200 loss: 1.595729
# batch 300 loss: 1.595374
# Train: Avg loss: 1.596489
# Validate: top1 Accuracy: 80.01%, Avg loss: 1.672260
#
#
#  ------ Epoch 81 ------
# current lr = 0.01
# batch 0 loss: 1.626790
# batch 100 loss: 1.595251
# batch 200 loss: 1.595952
# batch 300 loss: 1.596712
# Train: Avg loss: 1.597011
# Validate: top1 Accuracy: 80.23%, Avg loss: 1.670271
#
#
#  ------ Epoch 82 ------
# current lr = 0.01
# batch 0 loss: 1.588981
# batch 100 loss: 1.589493
# batch 200 loss: 1.592450
# batch 300 loss: 1.591897
# Train: Avg loss: 1.593123
# Validate: top1 Accuracy: 80.56%, Avg loss: 1.670526
#
#
#  ------ Epoch 83 ------
# current lr = 0.01
# batch 0 loss: 1.584296
# batch 100 loss: 1.588517
# batch 200 loss: 1.592308
# batch 300 loss: 1.592910
# Train: Avg loss: 1.592808
# Validate: top1 Accuracy: 80.24%, Avg loss: 1.670162
#
#
#  ------ Epoch 84 ------
# current lr = 0.01
# batch 0 loss: 1.615074
# batch 100 loss: 1.586355
# batch 200 loss: 1.588718
# batch 300 loss: 1.590615
# Train: Avg loss: 1.590348
# Validate: top1 Accuracy: 80.68%, Avg loss: 1.666759
#
#
#  ------ Epoch 85 ------
# current lr = 0.01
# batch 0 loss: 1.591683
# batch 100 loss: 1.585388
# batch 200 loss: 1.587016
# batch 300 loss: 1.588260
# Train: Avg loss: 1.588301
# Validate: top1 Accuracy: 80.81%, Avg loss: 1.663881
#
#
#  ------ Epoch 86 ------
# current lr = 0.01
# batch 0 loss: 1.576182
# batch 100 loss: 1.585389
# batch 200 loss: 1.586788
# batch 300 loss: 1.586401
# Train: Avg loss: 1.587279
# Validate: top1 Accuracy: 80.68%, Avg loss: 1.664439
#
#
#  ------ Epoch 87 ------
# current lr = 0.01
# batch 0 loss: 1.542428
# batch 100 loss: 1.585846
# batch 200 loss: 1.585826
# batch 300 loss: 1.586885
# Train: Avg loss: 1.586246
# Validate: top1 Accuracy: 80.18%, Avg loss: 1.668098
#
#
#  ------ Epoch 88 ------
# current lr = 0.01
# batch 0 loss: 1.566339
# batch 100 loss: 1.583213
# batch 200 loss: 1.583299
# batch 300 loss: 1.584766
# Train: Avg loss: 1.585369
# Validate: top1 Accuracy: 80.33%, Avg loss: 1.667998
#
#
#  ------ Epoch 89 ------
# current lr = 0.01
# batch 0 loss: 1.586457
# batch 100 loss: 1.582678
# batch 200 loss: 1.583353
# batch 300 loss: 1.582759
# Train: Avg loss: 1.583822
# Validate: top1 Accuracy: 80.72%, Avg loss: 1.667078
#
#
#  ------ Epoch 90 ------
# current lr = 0.01
# batch 0 loss: 1.628029
# batch 100 loss: 1.580802
# batch 200 loss: 1.579456
# batch 300 loss: 1.580751
# Train: Avg loss: 1.581478
# Validate: top1 Accuracy: 80.30%, Avg loss: 1.666402
#
#
#  ------ Epoch 91 ------
# current lr = 0.01
# batch 0 loss: 1.583880
# batch 100 loss: 1.576076
# batch 200 loss: 1.577683
# batch 300 loss: 1.578926
# Train: Avg loss: 1.580574
# Validate: top1 Accuracy: 81.13%, Avg loss: 1.663747
#
#
#  ------ Epoch 92 ------
# current lr = 0.01
# batch 0 loss: 1.549428
# batch 100 loss: 1.578607
# batch 200 loss: 1.577352
# batch 300 loss: 1.576897
# Train: Avg loss: 1.578464
# Validate: top1 Accuracy: 80.99%, Avg loss: 1.663530
#
#
#  ------ Epoch 93 ------
# current lr = 0.01
# batch 0 loss: 1.611802
# batch 100 loss: 1.576033
# batch 200 loss: 1.576509
# batch 300 loss: 1.577948
# Train: Avg loss: 1.578605
# Validate: top1 Accuracy: 80.75%, Avg loss: 1.669216
#
#
#  ------ Epoch 94 ------
# current lr = 0.01
# batch 0 loss: 1.588090
# batch 100 loss: 1.574704
# batch 200 loss: 1.575701
# batch 300 loss: 1.576389
# Train: Avg loss: 1.576876
# Validate: top1 Accuracy: 81.13%, Avg loss: 1.661390
#
#
#  ------ Epoch 95 ------
# current lr = 0.01
# batch 0 loss: 1.584625
# batch 100 loss: 1.572435
# batch 200 loss: 1.572190
# batch 300 loss: 1.573218
# Train: Avg loss: 1.573886
# Validate: top1 Accuracy: 80.71%, Avg loss: 1.665177
#
#
#  ------ Epoch 96 ------
# current lr = 0.01
# batch 0 loss: 1.630829
# batch 100 loss: 1.568184
# batch 200 loss: 1.569810
# batch 300 loss: 1.572370
# Train: Avg loss: 1.572700
# Validate: top1 Accuracy: 80.76%, Avg loss: 1.664852
#
#
#  ------ Epoch 97 ------
# current lr = 0.01
# batch 0 loss: 1.563033
# batch 100 loss: 1.572483
# batch 200 loss: 1.573706
# batch 300 loss: 1.574429
# Train: Avg loss: 1.573550
# Validate: top1 Accuracy: 80.82%, Avg loss: 1.663839
#
#
#  ------ Epoch 98 ------
# current lr = 0.01
# batch 0 loss: 1.527940
# batch 100 loss: 1.569547
# batch 200 loss: 1.568506
# batch 300 loss: 1.567917
# Train: Avg loss: 1.570397
# Validate: top1 Accuracy: 80.59%, Avg loss: 1.667051
#
#
#  ------ Epoch 99 ------
# current lr = 0.01
# batch 0 loss: 1.590242
# batch 100 loss: 1.567804
# batch 200 loss: 1.567757
# batch 300 loss: 1.566835
# Train: Avg loss: 1.568650
# Validate: top1 Accuracy: 81.26%, Avg loss: 1.659527
#
#
#  ------ Epoch 100 ------
# current lr = 0.01
# batch 0 loss: 1.597819
# batch 100 loss: 1.566974
# batch 200 loss: 1.568313
# batch 300 loss: 1.569449
# Train: Avg loss: 1.570010
# Validate: top1 Accuracy: 81.13%, Avg loss: 1.659336
#
#
#  ------ Epoch 101 ------
# current lr = 0.01
# batch 0 loss: 1.537332
# batch 100 loss: 1.567535
# batch 200 loss: 1.569678
# batch 300 loss: 1.569489
# Train: Avg loss: 1.570079
# Validate: top1 Accuracy: 81.57%, Avg loss: 1.660213
#
#
#  ------ Epoch 102 ------
# current lr = 0.01
# batch 0 loss: 1.568804
# batch 100 loss: 1.561559
# batch 200 loss: 1.566801
# batch 300 loss: 1.567209
# Train: Avg loss: 1.566640
# Validate: top1 Accuracy: 81.33%, Avg loss: 1.660175
#
#
#  ------ Epoch 103 ------
# current lr = 0.01
# batch 0 loss: 1.541021
# batch 100 loss: 1.561561
# batch 200 loss: 1.563507
# batch 300 loss: 1.563670
# Train: Avg loss: 1.564459
# Validate: top1 Accuracy: 81.59%, Avg loss: 1.656679
#
#
#  ------ Epoch 104 ------
# current lr = 0.01
# batch 0 loss: 1.567253
# batch 100 loss: 1.561776
# batch 200 loss: 1.562717
# batch 300 loss: 1.563952
# Train: Avg loss: 1.564055
# Validate: top1 Accuracy: 80.35%, Avg loss: 1.669429
#
#
#  ------ Epoch 105 ------
# current lr = 0.01
# batch 0 loss: 1.567751
# batch 100 loss: 1.558665
# batch 200 loss: 1.562972
# batch 300 loss: 1.564387
# Train: Avg loss: 1.564196
# Validate: top1 Accuracy: 81.29%, Avg loss: 1.659261
#
#
#  ------ Epoch 106 ------
# current lr = 0.01
# batch 0 loss: 1.580484
# batch 100 loss: 1.562638
# batch 200 loss: 1.563778
# batch 300 loss: 1.563726
# Train: Avg loss: 1.563797
# Validate: top1 Accuracy: 80.66%, Avg loss: 1.663829
#
#
#  ------ Epoch 107 ------
# current lr = 0.01
# batch 0 loss: 1.552808
# batch 100 loss: 1.561165
# batch 200 loss: 1.560703
# batch 300 loss: 1.562020
# Train: Avg loss: 1.561628
# Validate: top1 Accuracy: 81.27%, Avg loss: 1.659824
#
#
#  ------ Epoch 108 ------
# current lr = 0.01
# batch 0 loss: 1.560430
# batch 100 loss: 1.560647
# batch 200 loss: 1.557992
# batch 300 loss: 1.559130
# Train: Avg loss: 1.560899
# Validate: top1 Accuracy: 81.68%, Avg loss: 1.657037
#
#
#  ------ Epoch 109 ------
# current lr = 0.01
# batch 0 loss: 1.581074
# batch 100 loss: 1.559555
# batch 200 loss: 1.558970
# batch 300 loss: 1.558048
# Train: Avg loss: 1.560261
# Validate: top1 Accuracy: 81.50%, Avg loss: 1.659517
#
#
#  ------ Epoch 110 ------
# current lr = 0.01
# batch 0 loss: 1.559021
# batch 100 loss: 1.557102
# batch 200 loss: 1.559582
# batch 300 loss: 1.558732
# Train: Avg loss: 1.559738
# Validate: top1 Accuracy: 81.40%, Avg loss: 1.659372
#
#
#  ------ Epoch 111 ------
# current lr = 0.01
# batch 0 loss: 1.582479
# batch 100 loss: 1.558163
# batch 200 loss: 1.557146
# batch 300 loss: 1.556479
# Train: Avg loss: 1.556710
# Validate: top1 Accuracy: 81.61%, Avg loss: 1.659753
#
#
#  ------ Epoch 112 ------
# current lr = 0.01
# batch 0 loss: 1.574923
# batch 100 loss: 1.552863
# batch 200 loss: 1.555038
# batch 300 loss: 1.556547
# Train: Avg loss: 1.557752
# Validate: top1 Accuracy: 81.76%, Avg loss: 1.655127
#
#
#  ------ Epoch 113 ------
# current lr = 0.01
# batch 0 loss: 1.564112
# batch 100 loss: 1.552358
# batch 200 loss: 1.552534
# batch 300 loss: 1.553650
# Train: Avg loss: 1.554538
# Validate: top1 Accuracy: 81.34%, Avg loss: 1.659664
#
#
#  ------ Epoch 114 ------
# current lr = 0.01
# batch 0 loss: 1.594727
# batch 100 loss: 1.551630
# batch 200 loss: 1.554927
# batch 300 loss: 1.555489
# Train: Avg loss: 1.555481
# Validate: top1 Accuracy: 81.18%, Avg loss: 1.661393
#
#
#  ------ Epoch 115 ------
# current lr = 0.01
# batch 0 loss: 1.515517
# batch 100 loss: 1.551579
# batch 200 loss: 1.552597
# batch 300 loss: 1.552388
# Train: Avg loss: 1.553839
# Validate: top1 Accuracy: 81.39%, Avg loss: 1.659103
#
#
#  ------ Epoch 116 ------
# current lr = 0.01
# batch 0 loss: 1.518653
# batch 100 loss: 1.550876
# batch 200 loss: 1.552633
# batch 300 loss: 1.553662
# Train: Avg loss: 1.554011
# Validate: top1 Accuracy: 81.37%, Avg loss: 1.659316
#
#
#  ------ Epoch 117 ------
# current lr = 0.01
# batch 0 loss: 1.549082
# batch 100 loss: 1.550427
# batch 200 loss: 1.549964
# batch 300 loss: 1.551041
# Train: Avg loss: 1.552399
# Validate: top1 Accuracy: 81.08%, Avg loss: 1.660477
#
#
#  ------ Epoch 118 ------
# current lr = 0.01
# batch 0 loss: 1.571373
# batch 100 loss: 1.550023
# batch 200 loss: 1.553664
# batch 300 loss: 1.553477
# Train: Avg loss: 1.552206
# Validate: top1 Accuracy: 80.64%, Avg loss: 1.665360
#
#
#  ------ Epoch 119 ------
# current lr = 0.01
# batch 0 loss: 1.540874
# batch 100 loss: 1.549349
# batch 200 loss: 1.548150
# batch 300 loss: 1.549235
# Train: Avg loss: 1.551419
# Validate: top1 Accuracy: 80.78%, Avg loss: 1.665747
#
#
#  ------ Epoch 120 ------
# current lr = 0.001
# batch 0 loss: 1.539644
# batch 100 loss: 1.543362
# batch 200 loss: 1.539983
# batch 300 loss: 1.537872
# Train: Avg loss: 1.536806
# Validate: top1 Accuracy: 82.19%, Avg loss: 1.648718
#
#
#  ------ Epoch 121 ------
# current lr = 0.001
# batch 0 loss: 1.518769
# batch 100 loss: 1.537111
# batch 200 loss: 1.533947
# batch 300 loss: 1.532679
# Train: Avg loss: 1.532259
# Validate: top1 Accuracy: 82.28%, Avg loss: 1.647715
#
#
#  ------ Epoch 122 ------
# current lr = 0.001
# batch 0 loss: 1.516552
# batch 100 loss: 1.529644
# batch 200 loss: 1.530014
# batch 300 loss: 1.531730
# Train: Avg loss: 1.530710
# Validate: top1 Accuracy: 82.27%, Avg loss: 1.648398
#
#
#  ------ Epoch 123 ------
# current lr = 0.001
# batch 0 loss: 1.534513
# batch 100 loss: 1.528561
# batch 200 loss: 1.529220
# batch 300 loss: 1.530043
# Train: Avg loss: 1.529875
# Validate: top1 Accuracy: 82.32%, Avg loss: 1.648110
#
#
#  ------ Epoch 124 ------
# current lr = 0.001
# batch 0 loss: 1.539136
# batch 100 loss: 1.528170
# batch 200 loss: 1.528816
# batch 300 loss: 1.529162
# Train: Avg loss: 1.529423
# Validate: top1 Accuracy: 82.36%, Avg loss: 1.648921
#
#
#  ------ Epoch 125 ------
# current lr = 0.001
# batch 0 loss: 1.548035
# batch 100 loss: 1.532734
# batch 200 loss: 1.530184
# batch 300 loss: 1.528618
# Train: Avg loss: 1.528558
# Validate: top1 Accuracy: 82.30%, Avg loss: 1.646610
#
#
#  ------ Epoch 126 ------
# current lr = 0.001
# batch 0 loss: 1.544238
# batch 100 loss: 1.525958
# batch 200 loss: 1.528248
# batch 300 loss: 1.528064
# Train: Avg loss: 1.527628
# Validate: top1 Accuracy: 82.51%, Avg loss: 1.647044
#
#
#  ------ Epoch 127 ------
# current lr = 0.001
# batch 0 loss: 1.567626
# batch 100 loss: 1.525245
# batch 200 loss: 1.526032
# batch 300 loss: 1.526508
# Train: Avg loss: 1.527358
# Validate: top1 Accuracy: 82.40%, Avg loss: 1.646001
#
#
#  ------ Epoch 128 ------
# current lr = 0.001
# batch 0 loss: 1.506856
# batch 100 loss: 1.526927
# batch 200 loss: 1.524688
# batch 300 loss: 1.526135
# Train: Avg loss: 1.526940
# Validate: top1 Accuracy: 82.39%, Avg loss: 1.646787
#
#
#  ------ Epoch 129 ------
# current lr = 0.001
# batch 0 loss: 1.528198
# batch 100 loss: 1.526736
# batch 200 loss: 1.526632
# batch 300 loss: 1.526466
# Train: Avg loss: 1.526967
# Validate: top1 Accuracy: 82.46%, Avg loss: 1.647688
#
#
#  ------ Epoch 130 ------
# current lr = 0.001
# batch 0 loss: 1.513801
# batch 100 loss: 1.524088
# batch 200 loss: 1.525402
# batch 300 loss: 1.525728
# Train: Avg loss: 1.526670
# Validate: top1 Accuracy: 82.35%, Avg loss: 1.645287
#
#
#  ------ Epoch 131 ------
# current lr = 0.001
# batch 0 loss: 1.548209
# batch 100 loss: 1.524635
# batch 200 loss: 1.526685
# batch 300 loss: 1.526150
# Train: Avg loss: 1.526475
# Validate: top1 Accuracy: 82.26%, Avg loss: 1.646685
#
#
#  ------ Epoch 132 ------
# current lr = 0.001
# batch 0 loss: 1.519091
# batch 100 loss: 1.525290
# batch 200 loss: 1.526198
# batch 300 loss: 1.526041
# Train: Avg loss: 1.525642
# Validate: top1 Accuracy: 82.39%, Avg loss: 1.647414
#
#
#  ------ Epoch 133 ------
# current lr = 0.001
# batch 0 loss: 1.532101
# batch 100 loss: 1.525214
# batch 200 loss: 1.525461
# batch 300 loss: 1.525354
# Train: Avg loss: 1.525227
# Validate: top1 Accuracy: 82.55%, Avg loss: 1.646130
#
#
#  ------ Epoch 134 ------
# current lr = 0.001
# batch 0 loss: 1.553879
# batch 100 loss: 1.524820
# batch 200 loss: 1.525640
# batch 300 loss: 1.525638
# Train: Avg loss: 1.526199
# Validate: top1 Accuracy: 82.57%, Avg loss: 1.646516
#
#
#  ------ Epoch 135 ------
# current lr = 0.001
# batch 0 loss: 1.532404
# batch 100 loss: 1.524638
# batch 200 loss: 1.524572
# batch 300 loss: 1.525277
# Train: Avg loss: 1.525518
# Validate: top1 Accuracy: 82.38%, Avg loss: 1.645905
#
#
#  ------ Epoch 136 ------
# current lr = 0.001
# batch 0 loss: 1.516417
# batch 100 loss: 1.525638
# batch 200 loss: 1.522962
# batch 300 loss: 1.524139
# Train: Avg loss: 1.524359
# Validate: top1 Accuracy: 82.48%, Avg loss: 1.647480
#
#
#  ------ Epoch 137 ------
# current lr = 0.001
# batch 0 loss: 1.488330
# batch 100 loss: 1.523254
# batch 200 loss: 1.523828
# batch 300 loss: 1.524620
# Train: Avg loss: 1.524519
# Validate: top1 Accuracy: 82.38%, Avg loss: 1.647148
#
#
#  ------ Epoch 138 ------
# current lr = 0.0001
# batch 0 loss: 1.527633
# batch 100 loss: 1.527438
# batch 200 loss: 1.525227
# batch 300 loss: 1.524291
# Train: Avg loss: 1.524598
# Validate: top1 Accuracy: 82.47%, Avg loss: 1.645288
#
#
#  ------ Epoch 139 ------
# current lr = 0.0001
# batch 0 loss: 1.522494
# batch 100 loss: 1.523777
# batch 200 loss: 1.525059
# batch 300 loss: 1.524604
# Train: Avg loss: 1.524141
# Validate: top1 Accuracy: 82.42%, Avg loss: 1.646825
#
#
#  ------ Epoch 140 ------
# current lr = 0.0001
# batch 0 loss: 1.520118
# batch 100 loss: 1.522807
# batch 200 loss: 1.523707
# batch 300 loss: 1.523202
# Train: Avg loss: 1.523976
# Validate: top1 Accuracy: 82.42%, Avg loss: 1.646204
#
#
#  ------ Epoch 141 ------
# current lr = 0.0001
# batch 0 loss: 1.537396
# batch 100 loss: 1.522826
# batch 200 loss: 1.523369
# batch 300 loss: 1.522616
# Train: Avg loss: 1.523577
# Validate: top1 Accuracy: 82.43%, Avg loss: 1.645739
#
#
#  ------ Epoch 142 ------
# current lr = 0.0001
# batch 0 loss: 1.532538
# batch 100 loss: 1.525771
# batch 200 loss: 1.524908
# batch 300 loss: 1.524255
# Train: Avg loss: 1.523583
# Validate: top1 Accuracy: 82.38%, Avg loss: 1.648116
#
#
#  ------ Epoch 143 ------
# current lr = 0.0001
# batch 0 loss: 1.537719
# batch 100 loss: 1.527244
# batch 200 loss: 1.523664
# batch 300 loss: 1.523440
# Train: Avg loss: 1.523548
# Validate: top1 Accuracy: 82.41%, Avg loss: 1.646484
#
#
#  ------ Epoch 144 ------
# current lr = 0.0001
# batch 0 loss: 1.556506
# batch 100 loss: 1.522376
# batch 200 loss: 1.522847
# batch 300 loss: 1.522951
# Train: Avg loss: 1.523301
# Validate: top1 Accuracy: 82.42%, Avg loss: 1.645817
#
#
#  ------ Epoch 145 ------
# current lr = 0.0001
# batch 0 loss: 1.559335
# batch 100 loss: 1.523355
# batch 200 loss: 1.523554
# batch 300 loss: 1.523121
# Train: Avg loss: 1.523557
# Validate: top1 Accuracy: 82.40%, Avg loss: 1.647429
#
#
#  ------ Epoch 146 ------
# current lr = 0.0001
# batch 0 loss: 1.561458
# batch 100 loss: 1.523253
# batch 200 loss: 1.523611
# batch 300 loss: 1.524072
# Train: Avg loss: 1.523482
# Validate: top1 Accuracy: 82.35%, Avg loss: 1.645004
#
#
#  ------ Epoch 147 ------
# current lr = 0.0001
# batch 0 loss: 1.576701
# batch 100 loss: 1.525052
# batch 200 loss: 1.523024
# batch 300 loss: 1.523189
# Train: Avg loss: 1.523157
# Validate: top1 Accuracy: 82.50%, Avg loss: 1.645252
#
#
#  ------ Epoch 148 ------
# current lr = 0.0001
# batch 0 loss: 1.495147
# batch 100 loss: 1.521363
# batch 200 loss: 1.522908
# batch 300 loss: 1.522993
# Train: Avg loss: 1.522986
# Validate: top1 Accuracy: 82.53%, Avg loss: 1.644600
#
#
#  ------ Epoch 149 ------
# current lr = 1e-05
# batch 0 loss: 1.508074
# batch 100 loss: 1.522854
# batch 200 loss: 1.522210
# batch 300 loss: 1.523606
# Train: Avg loss: 1.523247
# Validate: top1 Accuracy: 82.49%, Avg loss: 1.647251
#
#
#  ------ Epoch 150 ------
# current lr = 1e-05
# batch 0 loss: 1.547848
# batch 100 loss: 1.524040
# batch 200 loss: 1.521329
# batch 300 loss: 1.522145
# Train: Avg loss: 1.522897
# Validate: top1 Accuracy: 82.46%, Avg loss: 1.647233
#
#
#  ------ Epoch 151 ------
# current lr = 1e-05
# batch 0 loss: 1.510354
# batch 100 loss: 1.522389
# batch 200 loss: 1.521895
# batch 300 loss: 1.523799
# Train: Avg loss: 1.523427
# Validate: top1 Accuracy: 82.49%, Avg loss: 1.645103
#
#
#  ------ Epoch 152 ------
# current lr = 1e-05
# batch 0 loss: 1.513132
# batch 100 loss: 1.522255
# batch 200 loss: 1.523282
# batch 300 loss: 1.522750
# Train: Avg loss: 1.522852
# Validate: top1 Accuracy: 82.46%, Avg loss: 1.647337
#
#
#  ------ Epoch 153 ------
# current lr = 1e-05
# batch 0 loss: 1.568549
# batch 100 loss: 1.521425
# batch 200 loss: 1.523010
# batch 300 loss: 1.523067
# Train: Avg loss: 1.522979
# Validate: top1 Accuracy: 82.43%, Avg loss: 1.647078
#
#
#  ------ Epoch 154 ------
# current lr = 1e-05
# batch 0 loss: 1.559871
# batch 100 loss: 1.524783
# batch 200 loss: 1.525208
# batch 300 loss: 1.523744
# Train: Avg loss: 1.523624
# Validate: top1 Accuracy: 82.48%, Avg loss: 1.646701
#
#
#  ------ Epoch 155 ------
# current lr = 1e-05
# batch 0 loss: 1.521160
# batch 100 loss: 1.524570
# batch 200 loss: 1.524395
# batch 300 loss: 1.524635
# Train: Avg loss: 1.523628
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.645367
#
#
#  ------ Epoch 156 ------
# current lr = 1e-05
# batch 0 loss: 1.515290
# batch 100 loss: 1.525524
# batch 200 loss: 1.524113
# batch 300 loss: 1.523163
# Train: Avg loss: 1.523210
# Validate: top1 Accuracy: 82.44%, Avg loss: 1.645889
#
#
#  ------ Epoch 157 ------
# current lr = 1e-05
# batch 0 loss: 1.541059
# batch 100 loss: 1.521450
# batch 200 loss: 1.521679
# batch 300 loss: 1.522793
# Train: Avg loss: 1.523050
# Validate: top1 Accuracy: 82.46%, Avg loss: 1.647059
#
#
#  ------ Epoch 158 ------
# current lr = 1e-05
# batch 0 loss: 1.548065
# batch 100 loss: 1.522780
# batch 200 loss: 1.522477
# batch 300 loss: 1.522152
# Train: Avg loss: 1.522680
# Validate: top1 Accuracy: 82.44%, Avg loss: 1.647108
#
#
#  ------ Epoch 159 ------
# current lr = 1e-05
# batch 0 loss: 1.510052
# batch 100 loss: 1.525245
# batch 200 loss: 1.523557
# batch 300 loss: 1.523261
# Train: Avg loss: 1.523696
# Validate: top1 Accuracy: 82.44%, Avg loss: 1.646793
#
#
#  ------ Epoch 160 ------
# current lr = 1.0000000000000002e-06
# batch 0 loss: 1.537487
# batch 100 loss: 1.520425
# batch 200 loss: 1.521487
# batch 300 loss: 1.522073
# Train: Avg loss: 1.522835
# Validate: top1 Accuracy: 82.44%, Avg loss: 1.647825
#
#
#  ------ Epoch 161 ------
# current lr = 1.0000000000000002e-06
# batch 0 loss: 1.491780
# batch 100 loss: 1.520340
# batch 200 loss: 1.522019
# batch 300 loss: 1.522708
# Train: Avg loss: 1.522622
# Validate: top1 Accuracy: 82.44%, Avg loss: 1.647642
#
#
#  ------ Epoch 162 ------
# current lr = 1.0000000000000002e-06
# batch 0 loss: 1.562632
# batch 100 loss: 1.520504
# batch 200 loss: 1.522822
# batch 300 loss: 1.522576
# Train: Avg loss: 1.522808
# Validate: top1 Accuracy: 82.44%, Avg loss: 1.644994
#
#
#  ------ Epoch 163 ------
# current lr = 1.0000000000000002e-06
# batch 0 loss: 1.566574
# batch 100 loss: 1.521053
# batch 200 loss: 1.520386
# batch 300 loss: 1.521212
# Train: Avg loss: 1.522551
# Validate: top1 Accuracy: 82.44%, Avg loss: 1.644838
#
#
#  ------ Epoch 164 ------
# current lr = 1.0000000000000002e-06
# batch 0 loss: 1.537157
# batch 100 loss: 1.525008
# batch 200 loss: 1.523520
# batch 300 loss: 1.523243
# Train: Avg loss: 1.523343
# Validate: top1 Accuracy: 82.44%, Avg loss: 1.645438
#
#
#  ------ Epoch 165 ------
# current lr = 1.0000000000000002e-06
# batch 0 loss: 1.518564
# batch 100 loss: 1.522499
# batch 200 loss: 1.523018
# batch 300 loss: 1.523442
# Train: Avg loss: 1.522909
# Validate: top1 Accuracy: 82.44%, Avg loss: 1.644922
#
#
#  ------ Epoch 166 ------
# current lr = 1.0000000000000002e-06
# batch 0 loss: 1.505008
# batch 100 loss: 1.524652
# batch 200 loss: 1.523172
# batch 300 loss: 1.523395
# Train: Avg loss: 1.523301
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.646389
#
#
#  ------ Epoch 167 ------
# current lr = 1.0000000000000002e-06
# batch 0 loss: 1.538580
# batch 100 loss: 1.523511
# batch 200 loss: 1.522685
# batch 300 loss: 1.522896
# Train: Avg loss: 1.522842
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.644358
#
#
#  ------ Epoch 168 ------
# current lr = 1.0000000000000002e-06
# batch 0 loss: 1.537358
# batch 100 loss: 1.522714
# batch 200 loss: 1.522730
# batch 300 loss: 1.522895
# Train: Avg loss: 1.523115
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.644472
#
#
#  ------ Epoch 169 ------
# current lr = 1.0000000000000002e-06
# batch 0 loss: 1.514919
# batch 100 loss: 1.524165
# batch 200 loss: 1.523453
# batch 300 loss: 1.522844
# Train: Avg loss: 1.523103
# Validate: top1 Accuracy: 82.46%, Avg loss: 1.644901
#
#
#  ------ Epoch 170 ------
# current lr = 1.0000000000000002e-06
# batch 0 loss: 1.507621
# batch 100 loss: 1.522439
# batch 200 loss: 1.522176
# batch 300 loss: 1.522619
# Train: Avg loss: 1.522747
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.646933
#
#
#  ------ Epoch 171 ------
# current lr = 1.0000000000000002e-07
# batch 0 loss: 1.522691
# batch 100 loss: 1.524092
# batch 200 loss: 1.523666
# batch 300 loss: 1.523665
# Train: Avg loss: 1.523784
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.644616
#
#
#  ------ Epoch 172 ------
# current lr = 1.0000000000000002e-07
# batch 0 loss: 1.506736
# batch 100 loss: 1.521966
# batch 200 loss: 1.522721
# batch 300 loss: 1.522315
# Train: Avg loss: 1.522831
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.646386
#
#
#  ------ Epoch 173 ------
# current lr = 1.0000000000000002e-07
# batch 0 loss: 1.508002
# batch 100 loss: 1.523742
# batch 200 loss: 1.522937
# batch 300 loss: 1.522938
# Train: Avg loss: 1.523844
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.646084
#
#
#  ------ Epoch 174 ------
# current lr = 1.0000000000000002e-07
# batch 0 loss: 1.508535
# batch 100 loss: 1.521003
# batch 200 loss: 1.522174
# batch 300 loss: 1.522830
# Train: Avg loss: 1.522855
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.645324
#
#
#  ------ Epoch 175 ------
# current lr = 1.0000000000000002e-07
# batch 0 loss: 1.518062
# batch 100 loss: 1.524857
# batch 200 loss: 1.523684
# batch 300 loss: 1.523790
# Train: Avg loss: 1.523015
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.644609
#
#
#  ------ Epoch 176 ------
# current lr = 1.0000000000000002e-07
# batch 0 loss: 1.518747
# batch 100 loss: 1.525514
# batch 200 loss: 1.523408
# batch 300 loss: 1.523422
# Train: Avg loss: 1.523319
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.645833
#
#
#  ------ Epoch 177 ------
# current lr = 1.0000000000000002e-07
# batch 0 loss: 1.530308
# batch 100 loss: 1.523261
# batch 200 loss: 1.522714
# batch 300 loss: 1.522989
# Train: Avg loss: 1.522604
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.646046
#
#
#  ------ Epoch 178 ------
# current lr = 1.0000000000000002e-07
# batch 0 loss: 1.501909
# batch 100 loss: 1.521817
# batch 200 loss: 1.522583
# batch 300 loss: 1.522508
# Train: Avg loss: 1.522514
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.645639
#
#
#  ------ Epoch 179 ------
# current lr = 1.0000000000000002e-07
# batch 0 loss: 1.515584
# batch 100 loss: 1.520862
# batch 200 loss: 1.523171
# batch 300 loss: 1.523372
# Train: Avg loss: 1.522931
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.645905
#
#
#  ------ Epoch 180 ------
# current lr = 1.0000000000000002e-07
# batch 0 loss: 1.515985
# batch 100 loss: 1.523544
# batch 200 loss: 1.522904
# batch 300 loss: 1.522768
# Train: Avg loss: 1.523099
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.644930
#
#
#  ------ Epoch 181 ------
# current lr = 1.0000000000000002e-07
# batch 0 loss: 1.521135
# batch 100 loss: 1.524589
# batch 200 loss: 1.523290
# batch 300 loss: 1.523859
# Train: Avg loss: 1.523516
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.647862
#
#
#  ------ Epoch 182 ------
# current lr = 1.0000000000000004e-08
# batch 0 loss: 1.596177
# batch 100 loss: 1.524055
# batch 200 loss: 1.525483
# batch 300 loss: 1.524125
# Train: Avg loss: 1.523768
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.645180
#
#
#  ------ Epoch 183 ------
# current lr = 1.0000000000000004e-08
# batch 0 loss: 1.478812
# batch 100 loss: 1.522849
# batch 200 loss: 1.521954
# batch 300 loss: 1.523649
# Train: Avg loss: 1.523189
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.645817
#
#
#  ------ Epoch 184 ------
# current lr = 1.0000000000000004e-08
# batch 0 loss: 1.556612
# batch 100 loss: 1.524343
# batch 200 loss: 1.523908
# batch 300 loss: 1.523349
# Train: Avg loss: 1.523173
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.646928
#
#
#  ------ Epoch 185 ------
# current lr = 1.0000000000000004e-08
# batch 0 loss: 1.531146
# batch 100 loss: 1.523666
# batch 200 loss: 1.522708
# batch 300 loss: 1.523040
# Train: Avg loss: 1.522797
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.644486
#
#
#  ------ Epoch 186 ------
# current lr = 1.0000000000000004e-08
# batch 0 loss: 1.523243
# batch 100 loss: 1.522043
# batch 200 loss: 1.523079
# batch 300 loss: 1.522424
# Train: Avg loss: 1.522817
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.644474
#
#
#  ------ Epoch 187 ------
# current lr = 1.0000000000000004e-08
# batch 0 loss: 1.533499
# batch 100 loss: 1.523756
# batch 200 loss: 1.523622
# batch 300 loss: 1.522548
# Train: Avg loss: 1.523158
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.644300
#
#
#  ------ Epoch 188 ------
# current lr = 1.0000000000000004e-08
# batch 0 loss: 1.548948
# batch 100 loss: 1.524002
# batch 200 loss: 1.523500
# batch 300 loss: 1.523236
# Train: Avg loss: 1.523196
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.644744
#
#
#  ------ Epoch 189 ------
# current lr = 1.0000000000000004e-08
# batch 0 loss: 1.535796
# batch 100 loss: 1.524430
# batch 200 loss: 1.522978
# batch 300 loss: 1.522980
# Train: Avg loss: 1.523072
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.644649
#
#
#  ------ Epoch 190 ------
# current lr = 1.0000000000000004e-08
# batch 0 loss: 1.510471
# batch 100 loss: 1.521123
# batch 200 loss: 1.521671
# batch 300 loss: 1.523166
# Train: Avg loss: 1.522652
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.644976
#
#
#  ------ Epoch 191 ------
# current lr = 1.0000000000000004e-08
# batch 0 loss: 1.544233
# batch 100 loss: 1.522350
# batch 200 loss: 1.523357
# batch 300 loss: 1.522993
# Train: Avg loss: 1.523365
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.645324
#
#
#  ------ Epoch 192 ------
# current lr = 1.0000000000000004e-08
# batch 0 loss: 1.499948
# batch 100 loss: 1.522267
# batch 200 loss: 1.524204
# batch 300 loss: 1.523176
# Train: Avg loss: 1.523128
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.646497
#
#
#  ------ Epoch 193 ------
# current lr = 1.0000000000000004e-08
# batch 0 loss: 1.502926
# batch 100 loss: 1.523924
# batch 200 loss: 1.523565
# batch 300 loss: 1.524026
# Train: Avg loss: 1.523086
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.645094
#
#
#  ------ Epoch 194 ------
# current lr = 1.0000000000000004e-08
# batch 0 loss: 1.517688
# batch 100 loss: 1.521769
# batch 200 loss: 1.522870
# batch 300 loss: 1.523453
# Train: Avg loss: 1.523491
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.645993
#
#
#  ------ Epoch 195 ------
# current lr = 1.0000000000000004e-08
# batch 0 loss: 1.513819
# batch 100 loss: 1.521404
# batch 200 loss: 1.521627
# batch 300 loss: 1.522990
# Train: Avg loss: 1.522826
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.645813
#
#
#  ------ Epoch 196 ------
# current lr = 1.0000000000000004e-08
# batch 0 loss: 1.541325
# batch 100 loss: 1.519709
# batch 200 loss: 1.522926
# batch 300 loss: 1.523238
# Train: Avg loss: 1.522607
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.646273
#
#
#  ------ Epoch 197 ------
# current lr = 1.0000000000000004e-08
# batch 0 loss: 1.537254
# batch 100 loss: 1.522713
# batch 200 loss: 1.523549
# batch 300 loss: 1.522808
# Train: Avg loss: 1.522710
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.645673
#
#
#  ------ Epoch 198 ------
# current lr = 1.0000000000000004e-08
# batch 0 loss: 1.524248
# batch 100 loss: 1.523649
# batch 200 loss: 1.523014
# batch 300 loss: 1.522768
# Train: Avg loss: 1.523267
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.644970
#
#
#  ------ Epoch 199 ------
# current lr = 1.0000000000000004e-08
# batch 0 loss: 1.519202
# batch 100 loss: 1.523507
# batch 200 loss: 1.523691
# batch 300 loss: 1.523459
# Train: Avg loss: 1.522892
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.645144

# %%
# plot training and validation metrics
plt.figure()
plt.subplot(2,2,1)
plt.plot(train_losses, label = "train loss")
plt.yscale("log")
plt.legend()
plt.subplot(2,2,2)
plt.plot(validate_losses, label = "validate loss")
plt.yscale("log")
plt.legend()
plt.subplot(2,2,3)
plt.plot(learning_rates, label = "learning rate")
plt.yscale("log")
plt.legend()
plt.subplot(2,2,4)
plt.plot(validate_accuracies, label = "accuracy")
plt.yscale("log")
plt.legend()
plt.tight_layout()
plt.show()

# %%
## validate for more top k calssification
for i_topk in range(1, 6):    
    cur_validate_loss, cur_validate_accuracy = validate_one_epoch_topk_aug(model, 
                                                                           validate_dataloader, 
                                                                           loss_func, 
                                                                           validate_transforms, 
                                                                           device, 
                                                                           i_topk)
# Out:
# Validate: top1 Accuracy: 82.45%, Avg loss: 1.647188
# Validate: top2 Accuracy: 92.74%, Avg loss: 1.646633
# Validate: top3 Accuracy: 96.23%, Avg loss: 1.645810
# Validate: top4 Accuracy: 97.82%, Avg loss: 1.645605
# Validate: top5 Accuracy: 98.87%, Avg loss: 1.644081

# %%
## save model and model parameters

dst_dir_path = r".\Results"
if not os.path.isdir(dst_dir_path):
    os.makedirs(dst_dir_path)

dst_model_name = "model_" + time.strftime("%Y-%m-%d-%H-%M-%S", time.localtime())
dst_model_file_name = dst_model_name + ".pt"
dst_modelstate_file_name = dst_model_name + "_state.pt"

dst_model_file_path = os.path.join(dst_dir_path, dst_model_file_name)
torch.save(model, dst_model_file_path)
print("model saved to: " + dst_model_file_path)

dst_modelstate_file_path = os.path.join(dst_dir_path, dst_modelstate_file_name)
torch.save(model.state_dict(), dst_modelstate_file_path)
print("model state saved to: " + dst_modelstate_file_path)
# Out:
# model saved to: .\Results\model_2024-05-13-09-16-08.pt
# model state saved to: .\Results\model_2024-05-13-09-16-08_state.pt
